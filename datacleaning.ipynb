# %%
import pandas as pd

# %%
us_df = pd.read_excel("Data/US_Bretton_Woods_Data.xlsx", header = 1)

# %%
us_df
# Out:
#     Unnamed: 0  Economic Activity, Industrial Production, Index  \
# 0     Jan 1960                                        26.794824
# 1     Feb 1960                                        26.944960
# 2     Mar 1960                                        26.883139
# 3     Apr 1960                                        26.671183
# 4     May 1960                                        26.609362
# ..         ...                                              ...
# 367   Aug 1990                                        69.548201
# 368   Sep 1990                                        70.078092
# 369   Oct 1990                                        69.133119
# 370   Nov 1990                                        67.340321
# 371   Dec 1990                                        66.351191
#
#      Exchange Rates, SDR per US Dollar, Period Average  \
# 0                                              1.00000
# 1                                              1.00000
# ...

# %%
us_df.loc[0]
# Out:
# Unnamed: 0                                                                             Jan 1960
# Economic Activity, Industrial Production, Index                                       26.794824
# Exchange Rates, SDR per US Dollar, Period Average                                           1.0
# International Reserves and Liquidity, Reserves, Official Reserve Assets, US Dollar      21478.1
# Prices, Consumer Price Index, All items, Index                                        13.436946
# Name: 0, dtype: object

# %% [markdown]
# # YOOOOOOOO

# %% [markdown]
# # Second edit :))))

# %%
us_df.rename(columns={'Unnamed: 0':'Month','Economic Activity, Industrial Production, Index': 'Industrial_Production', 'Exchange Rates, SDR per US Dollar, Period Average':'Exchange_Rate', 'International Reserves and Liquidity, Reserves, Official Reserve Assets, US Dollar':
                      'International_Reserves_Liquidity', 'Prices, Consumer Price Index, All items, Index':'CPI'})
# Out:
#         Month  Industrial_Production  Exchange_Rate  \
# 0    Jan 1960              26.794824        1.00000
# 1    Feb 1960              26.944960        1.00000
# 2    Mar 1960              26.883139        1.00000
# 3    Apr 1960              26.671183        1.00000
# 4    May 1960              26.609362        1.00000
# ..        ...                    ...            ...
# 367  Aug 1990              69.548201        0.72612
# 368  Sep 1990              70.078092        0.71917
# 369  Oct 1990              69.133119        0.70006
# 370  Nov 1990              67.340321        0.69213
# 371  Dec 1990              66.351191        0.70100
#
#      International_Reserves_Liquidity        CPI
# 0                        21478.100000  13.436946
# 1                        21395.700000  13.482806
# 2                        21344.700000  13.482806
# 3                        21278.000000  13.528666
# 4                        21234.300000  13.528666
# ...

# %% [markdown]
# testing lol

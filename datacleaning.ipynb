# %%
import pandas as pd

# %%
us_df = pd.read_excel("Data/US_Bretton_woods_data.xlsx", header = 1)

# %%
us_df
# Out:
#     Unnamed: 0  Economic Activity, Industrial Production, Index  \
# 0         1960                                        26.187777
# 1     Jan 1960                                        26.794824
# 2     Feb 1960                                        26.944960
# 3     Mar 1960                                        26.883139
# 4     Apr 1960                                        26.671183
# ..         ...                                              ...
# 398   Aug 1990                                        69.548201
# 399   Sep 1990                                        70.078092
# 400   Oct 1990                                        69.133119
# 401   Nov 1990                                        67.340321
# 402   Dec 1990                                        66.351191
#
#      Exchange Rates, SDR per US Dollar, Period Average  \
# 0                                              1.00000
# 1                                              1.00000
# ...

# %% [markdown]
# # YOOOOOOOO

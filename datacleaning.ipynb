# %%
import pandas as pd

# %%
us_df = pd.read_excel("Data/US_Bretton_woods_data.xlsx")

# %%
us_df
# Out:
#     International Financial Statistics (IFS)  \
# 0                                        NaN
# 1                                       1960
# 2                                   Jan 1960
# 3                                   Feb 1960
# 4                                   Mar 1960
# ..                                       ...
# 399                                 Aug 1990
# 400                                 Sep 1990
# 401                                 Oct 1990
# 402                                 Nov 1990
# 403                                 Dec 1990
#
#                                           Unnamed: 1  \
# 0    Economic Activity, Industrial Production, Index
# 1                                          26.187777
# 2                                          26.794824
# 3                                           26.94496
# 4                                          26.883139
# ..                                               ...
# ...
